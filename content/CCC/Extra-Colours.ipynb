# %% [markdown]
# <h3>ADD STARTING INFORMATION HERE</h3>
# *Making your own colour maps*

# %% [markdown]
# <h3>Set up</h3>

# %%
# import libraries
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import ListedColormap
import functions as s

# %% [markdown]
# 1. Run the cell above to reload the important libraries. Wait until [*] has changed to [1] before carrying on.
# 2. Edit the cell below, adding your chosen image, colour map, and any extra information you have added such as a colour bar or title.

# %%
my_Image = s.convert( "London.jpg" )
plt.imshow(my_Image, cmap='rainbow')
s.tidy_plot()
# Out:
# original: JPEG RGB (1536, 703)
# array:  uint8 (653, 1536, 3)

# %% [markdown]
# <h3>Creating your own colour map</h3>
# **You can further edit your new image by making your own colour map, with colours of your choice**<br>
# *Link here to colour names website*<br>
# *Some further instructions...*

# %%
colours1 = ListedColormap(["darkorange", "gold", "lawngreen", "lightseagreen"])
mpl.colormaps.register(cmap=colours1)

# %% [markdown]
# **BECAUSE OF THE WAY THINGS ARE SAVED IN JUPYTER, THE ABOVE CODE WILL ERROR IF YOU RUN IT MORE THAN ONCE<br>
# WHENEVER YOU MAKE CHANGES TO YOUR LIST/S OF COLOURS, CLICK RESTART KERNEL AND THEN RUN ALL OF YOUR CELLS AGAIN**

# %%
plt.imshow(my_Image, cmap=colours1) # CHANGE TO YOUR FAVOURITE COLOUR MAP
s.tidy_plot()
plt.colorbar(orientation='horizontal')
