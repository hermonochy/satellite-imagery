# %% [markdown]
# **ADD STARTING INFORMATION HERE**

# %%
# import all necessary libraries
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import functions as ccc

# %% [markdown]
# **The next cell runs code to plot your image as a graph - it looks like an image, but has axes showing the number of pixels**

# %%
my_Image = ccc.convert( "Oxford_Landsat_NDVI.jpg" )
# add some info here about changing the image - we will have three available to use.
# when you have finished experimenting, choose the image you want to use for the next part of the workshop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15940\2085273858.py in <module>
# ----> 1 my_Image = ccc.convert( "Oxford_Landsat_NDVI.jpg" )
#       2 # add some info here about changing the image - we will have three available to use.
#       3 # when you have finished experimenting, choose the image you want to use for the next part of the workshop
#
# c:\Users\sarah.townson\github\satellite-imagery\content\CCC\functions.py in convert(image)
#       6 def convert(image):
#       7     # open the original image, and show its filetype, colour mode and size
# ----> 8     original = Image.open(image)
#       9     print("original:", original.format, original.mode, original.size)
#      10     # the filetype should be JPEG or PNG; the colour mode should be RGB
#
# NameError: name 'Image' is not defined

# %%
plt.imshow(my_Image)

# %% [markdown]
# **Ignore the numbers, they are showing you how many pixels make up your image (how big it is), and have nothing to do with the colours.
# <br>
# What do you think the images are showing? What are the light sections, what are the dark sections, what are the grey parts?**

# %% [markdown]
# You can change the colours to get an image that you are happy with.<br>
# What colours do you think would be best to present your data?<br>
# <br>
# Options = 'magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c'
# <br>
# <br>
# *To reverse the colours, add _r to the end of each of the colour maps!*

# %% [markdown]
# **In the code below, we have chosen the colour map 'inferno_r'.<br>
# Test out a few of the options listed above, and see which ones you like best.**

# %%
plt.imshow(my_Image, cmap='inferno') # CHANGE TO ANOTHER COLOUR MAP AND TEST

# %% [markdown]
# Now we will tidy this up a bit - remove the unncessary numbers, and add a key for the colours.

# %%
plt.imshow(my_Image, cmap='hot_r') # CHANGE TO YOUR FAVOURITE COLOUR MAP
ccc.tidy_plot()
plt.colorbar(orientation='horizontal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15940\2319902386.py in <module>
#       1 plt.imshow(my_Image, cmap='hot_r') # CHANGE TO YOUR FAVOURITE COLOUR MAP
# ----> 2 ccc.tidy_plot()
#       3 plt.colorbar(orientation='horizontal')
#
# c:\Users\sarah.townson\github\satellite-imagery\content\CCC\functions.py in tidy_plot()
#      40     because they only show the size of the image, they can be misleading and are not needed for this workshop
#      41     '''
# ---> 42     plt.xticks([])
#      43     plt.yticks([])
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **Take a break from coding to choose some infrared images of your own to analyse.<br>
# INSTRUCTIONS FOR USING SENTINEL HUB HERE<br>
# Also instructions on how to add your image into the notebook**

# %%
# edit this code to test your new image

my_Image = ccc.convert( "London_Landsat_NDVI.jpg" ) # EDIT THIS FOR YOUR NEW IMAGE OR PIC YOUR FAVOURITE ONE OF OURS
plt.imshow(my_Image, cmap='rainbow') # CHANGE TO YOUR FAVOURITE COLOUR MAP
ccc.tidy_plot()
plt.colorbar(orientation='horizontal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15940\134165520.py in <module>
#       1 # edit this code to test your new image
#       2
# ----> 3 my_Image = ccc.convert( "London_Landsat_NDVI.jpg" ) # EDIT THIS FOR YOUR NEW IMAGE OR PIC YOUR FAVOURITE ONE OF OURS
#       4 plt.imshow(my_Image, cmap='rainbow') # CHANGE TO YOUR FAVOURITE COLOUR MAP
#       5 ccc.tidy_plot()
#
# c:\Users\sarah.townson\github\satellite-imagery\content\CCC\functions.py in convert(image)
#       6 def convert(image):
#       7     # open the original image, and show its filetype, colour mode and size
# ----> 8     original = Image.open(image)
#       9     print("original:", original.format, original.mode, original.size)
#      10     # the filetype should be JPEG or PNG; the colour mode should be RGB
#
# NameError: name 'Image' is not defined

# %% [markdown]
# **Add some information about your chosen image, so that people understand what it means.<br>
# Labels, add a title etc.**

# %%
plt.imshow(my_Image, cmap='magma_r') # CHANGE TO YOUR FAVOURITE COLOUR MAP
ccc.tidy_plot()
plt.title('THIS IS THE TITLE OF MY IMAGE')
plt.colorbar(orientation='horizontal', label='lighter colours indicate healthier vegetation')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15940\3836016291.py in <module>
#       1 plt.imshow(my_Image, cmap='magma_r') # CHANGE TO YOUR FAVOURITE COLOUR MAP
# ----> 2 ccc.tidy_plot()
#       3 plt.title('THIS IS THE TITLE OF MY IMAGE')
#       4 plt.colorbar(orientation='horizontal', label='lighter colours indicate healthier vegetation')
#
# c:\Users\sarah.townson\github\satellite-imagery\content\CCC\functions.py in tidy_plot()
#      40     because they only show the size of the image, they can be misleading and are not needed for this workshop
#      41     '''
# ---> 42     plt.xticks([])
#      43     plt.yticks([])
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **HOW TO SAVE YOUR IMAGES**<br>
# Add instuctions here...
